# %%
# Welcome back, I am excited to showcase this next part!
# This moves up a folder to access the juicy .py data
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
"""
Dynamic Airline Factor Laboratory
_______
Rolling covariance, rolling PCA via eigendecomposition, factor model,
residual (mispricing) computation, and rolling z-score generation.

Signal Timing — No Look-Ahead Bias
_______
The central timing discipline of this module:

    Day t-W  ───────────────────  Day t-1  |  Day t
    [rolling covariance estimation window] |  r_t arrives
                                           |  residual computed
                                           |  z-score computed
                                           |  SIGNAL formed
                                           |  Day t+1: position executed

Concretely: the covariance matrix "dated" t uses returns [t-W, t-1].
Day t's return is NEVER inside its own covariance estimation window.
The residual at day t is computed using eigenvectors from [t-W, t-1].
Positions are then shifted one day before backtesting (executed at t+1).

Mathematical Framework
_______
Let  R ∈ ℝ^{T × N}  be the matrix of daily log returns for N airlines.

(1) COVARIANCE  (at date t, using W days ending at t-1)
        Σ_t = 1/(W-1) · (R_w - μ_w)ᵀ (R_w - μ_w) × 252

(2) EIGENDECOMPOSITION
        Σ_t = Q Λ Qᵀ
        Q ∈ ℝ^{N×N}: columns are orthonormal eigenvectors (principal components)
        Λ ∈ ℝ^{N×N}: diagonal eigenvalue matrix, λ₁ ≥ λ₂ ≥ … ≥ λ_N

        Explained variance ratio:  EVR_i = λ_i / Σ_j λ_j

(3) SYSTEMATIC COMPONENT  (factor model projection)
        f_t    = Q_kᵀ r_t           ∈ ℝ^k   (factor returns)
        r̂_t   = Q_k Q_kᵀ r_t       ∈ ℝ^N   (systematic component)
        where Q_k = first k columns of Q (top k eigenvectors)
        P = Q_k Q_kᵀ is the rank-k projection matrix onto factor space.

(4) RESIDUAL  (relative mispricing)
        ε_t = (I − P) r_t           ∈ ℝ^N
        The component of returns orthogonal to all k common factors.
        Under the mean-reversion hypothesis, |ε_t| is stationary.

(5) Z-SCORE
        z_{i,t} = (ε_{i,t} − μ_{ε,i}) / σ_{ε,i}
        where μ and σ are rolling 30-day mean and std of residuals.

Framing Note
_______
The residual ε_t is NOT an "expected return." It is a relative mispricing:
the portion of airline i's return on day t that cannot be attributed to the
k common airline risk factors identified by PCA. The trading hypothesis is
that unusually large residuals (|z| > 2) tend to mean-revert, implying
that airline i is temporarily mispriced relative to its peers.
"""
# Out:
# '\nDynamic Airline Factor Laboratory\n_______\nRolling covariance, rolling PCA via eigendecomposition, factor model,\nresidual (mispricing) computation, and rolling z-score generation.\n\nSignal Timing — No Look-Ahead Bias\n_______\nThe central timing discipline of this module:\n\n    Day t-W  ───────────────────  Day t-1  |  Day t\n    [rolling covariance estimation window] |  r_t arrives\n                                           |  residual computed\n                                           |  z-score computed\n                                           |  SIGNAL formed\n                                           |  Day t+1: position executed\n\nConcretely: the covariance matrix "dated" t uses returns [t-W, t-1].\nDay t\'s return is NEVER inside its own covariance estimation window.\nThe residual at day t is computed using eigenvectors from [t-W, t-1].\nPositions are then shifted one day before backtesting (executed at t+1).\n\nMathematical Framework\n_______\nLet  R ∈ ℝ^{T × N}  be the matrix of daily log returns for N airlines.\n\n(1) COVARIANCE  (at date t, using W days ending at t-1)\n        Σ_t = 1/(W-1) · (R_w - μ_w)ᵀ (R_w - μ_w) × 252\n\n(2) EIGENDECOMPOSITION\n        Σ_t = Q Λ Qᵀ\n        Q ∈ ℝ^{N×N}: columns are orthonormal eigenvectors (principal components)\n        Λ ∈ ℝ^{N×N}: diagonal eigenvalue matrix, λ₁ ≥ λ₂ ≥ … ≥ λ_N\n\n        Explained variance ratio:  EVR_i = λ_i / Σ_j λ_j\n\n(3) SYSTEMATIC COMPONENT  (factor model projection)\n        f_t    = Q_kᵀ r_t           ∈ ℝ^k   (factor returns)\n        r̂_t   = Q_k Q_kᵀ r_t       ∈ ℝ^N   (systematic component)\n        where Q_k = first k columns of Q (top k eigenvectors)\n        P = Q_k Q_kᵀ is the rank-k projection matrix onto factor space.\n\n(4) RESIDUAL  (relative mispricing)\n        ε_t = (I − P) r_t           ∈ ℝ^N\n        The component of returns orthogonal to all k common factors.\n        Under the mean-reversion hypothesis, |ε_t| is stationary.\n\n(5) Z-SCORE\n        z_{i,t} = (ε_{i,t} − μ_{ε,i}) / σ_{ε,i}\n        where μ and σ are rolling 30-day mean and std of residuals.\n\nFraming Note\n_______\nThe residual ε_t is NOT an "expected return." It is a relative mispricing:\nthe portion of airline i\'s return on day t that cannot be attributed to the\nk common airline risk factors identified by PCA. The trading hypothesis is\nthat unusually large residuals (|z| > 2) tend to mean-revert, implying\nthat airline i is temporarily mispriced relative to its peers.\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import data as dt
import models as md

# %%
airline_returns, macro_returns, prices = dt.load_data()
# Out:
# Downloading 10 tickers [2015-01-01 -> 2026-07-17] ...
# Airlines : 6 tickers
# Macro : 4 tickers
# Dates : 2903 trading days
# Range: 2015-01-05 -> 2026-07-16
# Training : 2015-01-05 -> 2019-12-31
# Validation: 2022-01-01 -> 2026-07-16

# %%
covs = md.rolling_covariances(airline_returns)

# %%
len(covs)
# Out:
# 2813

# %%
first_date = list(covs.keys())[0]
covs[first_date]
# Out:
# array([[0.10846763, 0.10308314, 0.10708398, 0.08392898, 0.07348095,
#         0.07550351],
#        [0.10308314, 0.14172933, 0.11857634, 0.09864836, 0.08649149,
#         0.08898063],
#        [0.10708398, 0.11857634, 0.14811941, 0.09623216, 0.08491586,
#         0.0895048 ],
#        [0.08392898, 0.09864836, 0.09623216, 0.10810451, 0.07920877,
#         0.08527415],
#        [0.07348095, 0.08649149, 0.08491586, 0.07920877, 0.08807498,
#         0.07108457],
#        [0.07550351, 0.08898063, 0.0895048 , 0.08527415, 0.07108457,
#         0.13337066]])

# %%
eigvals,eigvecs,evr = md.run_pca(covs[first_date])

# %%
eig_df = pd.DataFrame(
    {
        "Eigenvalue": eigvals,
        "Explained Variance": evr
    },
    index=["PC1", "PC2"]
)
eig_df
# Out:
#      Eigenvalue  Explained Variance
# PC1    0.574547            0.789357
# PC2    0.060266            0.082798

# %%
loading_df = pd.DataFrame(
    eigvecs,
    index=airline_returns.columns,
    columns=["PC1", "PC2"]
)
loading_df
# Out:
#              PC1       PC2
# Ticker
# DAL     0.394825 -0.269576
# UAL     0.458040 -0.249554
# AAL     0.463951 -0.329945
# LUV     0.392122  0.098162
# ALK     0.342163  0.007855
# JBLU    0.385002  0.863997

# %%
plt.figure(figsize=(6,4))
plt.imshow(loading_df.T, aspect="auto")
plt.xticks(range(len(loading_df.index)), loading_df.index)
plt.yticks([0,1], ["PC1", "PC2"])
plt.colorbar(label="Loading")
plt.title("Principal Component Loadings")
plt.show()

# %%
evr
# Out:
# array([0.78935723, 0.0827984 ])

# %%
systematic,residuals,evals,evecs,explained = \
md.compute_factor_model(
    airline_returns,
    covs
)

# %%
residuals.head()
# Out:
#                  DAL       UAL       AAL       LUV       ALK      JBLU
# 2015-05-14  0.000936 -0.005523 -0.007633  0.009451  0.011907 -0.005400
# 2015-05-15 -0.005345  0.001106  0.000579 -0.002733  0.008057 -0.000964
# 2015-05-18  0.000509  0.000803 -0.002448 -0.004929  0.007230  0.000023
# 2015-05-19 -0.002322  0.001261  0.002314 -0.012471  0.010363  0.001399
# 2015-05-20  0.023334 -0.014754 -0.008982 -0.016968  0.022729  0.001700

# %%
zscores = md.compute_rolling_zscore(residuals)
zscores["DAL"].plot(figsize=(12,5))
plt.axhline(2,color="red")
plt.axhline(-2,color="red")
plt.axhline(0,color="black")

# %%
factor_returns = md.compute_factor_returns(
    airline_returns,
    covs
)
factor_returns.head()
# Out:
#                  PC1       PC2
# 2015-05-14  0.028717 -0.003309
# 2015-05-15 -0.007190  0.001006
# 2015-05-18  0.026113  0.010314
# 2015-05-19 -0.046587  0.014266
# 2015-05-20 -0.202570  0.004181

# %%
pc1 = md.compute_pc1_concentration(covs)
pc1.plot(figsize=(12,5))
# Out:
# <Axes: >
