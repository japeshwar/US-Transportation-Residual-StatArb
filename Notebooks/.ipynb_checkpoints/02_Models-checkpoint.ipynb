# %%
# Welcome back, I am excited to showcase this next part!
# This moves up a folder to access the .py data
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
# The Classics
import warnings; warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
import data as dt
import models as md
import backtest as bt
output_dir = Path("../Outputs")
output_dir.mkdir(exist_ok = True)
print("Imports Ok")
# Out:
# Imports Ok

# %%
# Download data
stocks_returns, macro_returns, prices = dt.load_data()
print("Computing simple residuals vs. SPY + IYT ...")
factor_returns = macro_returns[['SPY', 'IYT']]
residuals = md.compute_simple_residuals(stocks_returns, factor_returns, window = 90)
zscores = md.compute_rolling_zscore(residuals, window = 45)
print("Residuals shape:", residuals.shape)
print("Z-scores shape:", zscores.shape)
print("First valid date:", residuals.dropna(how = 'all').index[0].date())
# Out:
# ...
# Dropped 569 rows with missing data
# Clean returns: 2336 observations, 22 assets
# Stocks: 20 tickers
# Macro columns: ['SPY', 'IYT', 'Brent', 'VIX']
# Dates: 2336 trading days
# Range: 2017-04-07 -> 2026-07-30
# Computing simple residuals vs. SPY + IYT ...
# Residuals shape: (2336, 20)
# Z-scores shape: (2336, 20)
# First valid date: 2017-08-16

# %%
# The strategy revolves around finding the most extreme discrepancies and trading off the mean reversion
print(zscores.describe().round(3))
print(f"\n% of days |z| > {bt.entry_threshold}: {(zscores.abs() > bt.entry_threshold).mean().mean():.2%}")
# Out:
# Ticker       DAL       UAL       AAL       LUV       ALK      JBLU       UNP  \
# count   2237.000  2237.000  2237.000  2237.000  2237.000  2237.000  2237.000
# mean      -0.007    -0.005     0.004     0.001     0.005     0.007    -0.002
# std        1.003     1.012     0.998     1.000     1.010     1.008     0.999
# min       -5.649    -5.146    -4.566    -4.799    -5.048    -4.988    -4.986
# 25%       -0.581    -0.573    -0.546    -0.549    -0.620    -0.567    -0.596
# 50%       -0.031    -0.040    -0.024     0.016     0.013    -0.011    -0.021
# 75%        0.574     0.566     0.530     0.576     0.609     0.572     0.584
# max        4.086     5.171     5.251     4.765     4.188     3.936     4.815
#
# Ticker       CSX       NSC        CP       CNI       UPS       FDX      JBHT  \
# count   2237.000  2237.000  2237.000  2237.000  2237.000  2237.000  2237.000
# mean      -0.001    -0.002    -0.004     0.005     0.002     0.003    -0.005
# ...

# %%
# Thanks for your time, allow me to take you to the next Exhibit (03_Backtest.ipynb)!
