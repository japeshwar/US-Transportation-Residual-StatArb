# %%
# Welcome to Japeshwar Singh's project, but please call me Jay :)
# This moves up a folder to access the juicy .py data
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
# The Classics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import data as dt
import models as md

# %%
# Starting Data
airline_returns, macro_returns, prices = dt.load_data()
print(airline_returns.shape)
airline_returns.head()
# Out:
# ...
# Airlines : 6 tickers
# Macro : 4 tickers
# Dates : 2903 trading days
# Range: 2015-01-05 -> 2026-07-16
# Training : 2015-01-05 -> 2019-12-31
# Validation: 2022-01-01 -> 2026-07-16
# (2903, 6)
# Ticker           DAL       UAL       AAL       LUV       ALK      JBLU
# Date
# 2015-01-05 -0.016814 -0.002868 -0.000557 -0.024904 -0.014357 -0.036766
# 2015-01-06 -0.023856 -0.024020 -0.015713 -0.028747 -0.011841 -0.016562
# 2015-01-07 -0.005308  0.014603 -0.000566  0.008368  0.015198  0.008647
# 2015-01-08  0.025642  0.016797  0.012187  0.026126  0.017114 -0.014677
# 2015-01-09 -0.027561 -0.019701 -0.031040 -0.026371 -0.016109 -0.034180

# %%
# General Overview on the Plan
"""
This is the Dynamic Airline Factor Laboratory, where instead of parts we will be manufacturing Sharpe
Downloads, cleans, and prepares market data for the rolling PCA statistical arbitrage pipeline.
Within this magnificent universe, we shall evaluate DAL, UAL, AAL, LUV, ALK, JBLU against the benchmark S&P 500
While we could have studied LATAM, Azul, GOL and Copa, we are excluding them due to exclusivity of the US Market.
Asides from the S&P 500, we will include BZ=F (Brent Crude) and the ^VIX (CBOE Volatility Index) as the risk-regime litmus test
Training: 2015-01-01 --> 2019-12-31
Validation: 2022-01-01 --> 2026-07-17
"""
# Out:
# '\nThis is the Dynamic Airline Factor Laboratory, where instead of parts we will be manufacturing Sharpe\nDownloads, cleans, and prepares market data for the rolling PCA statistical arbitrage pipeline.\nWithin this magnificent universe, we shall evaluate DAL, UAL, AAL, LUV, ALK, JBLU against the benchmark S&P 500\nWhile we could have studied LATAM, Azul, GOL and Copa, we are excluding them due to exclusivity of the US Market.\nAsides from the S&P 500, we will include BZ=F (Brent Crude) and the ^VIX (CBOE Volatility Index) as the risk-regime litmus test\nTraining: 2015-01-01 --> 2019-12-31\nValidation: 2022-01-01 --> 2026-07-17\n'

# %%
# All Prices
prices.head()
# Out:
# Ticker            AAL        ALK      Brent        DAL   JBLU  JETS  \
# Date
# 2015-01-02  51.079914  55.159012  56.419998  42.729156  15.79   NaN
# 2015-01-05  51.051483  54.372726  53.110001  42.016720  15.22   NaN
# 2015-01-06  50.255585  53.732719  51.099998  41.026241  14.97   NaN
# 2015-01-07  50.227154  54.555580  51.150002  40.809040  15.10   NaN
# 2015-01-08  50.843033  55.497303  50.959999  41.869015  14.88   NaN
#
# Ticker            LUV         SPY        UAL        VIX
# Date
# 2015-01-02  37.374599  169.687881  66.339996  17.790001
# 2015-01-05  36.455334  166.623306  66.150002  19.920000
# 2015-01-06  35.422256  165.053970  64.580002  21.120001
# 2015-01-07  35.719929  167.110641  65.529999  19.309999
# 2015-01-08  36.665455  170.076096  66.639999  17.010000

# %%
# Basic Information
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2904 entries, 2015-01-02 to 2026-07-16
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAL     2900 non-null   float64
#  1   ALK     2900 non-null   float64
#  2   Brent   2901 non-null   float64
#  3   DAL     2900 non-null   float64
#  4   JBLU    2900 non-null   float64
#  5   JETS    2819 non-null   float64
#  6   LUV     2900 non-null   float64
#  7   SPY     2900 non-null   float64
#  8   UAL     2900 non-null   float64
#  9   VIX     2901 non-null   float64
# dtypes: float64(10)
# memory usage: 249.6 KB

# %%
# Missing Values
prices.isna().sum()
# Out:
# Ticker
# AAL       4
# ALK       4
# Brent     3
# DAL       4
# JBLU      4
# JETS     85
# LUV       4
# SPY       4
# UAL       4
# VIX       3
# dtype: int64

# %%
# Summary Statistics
prices.describe()
# Out:
# Ticker          AAL          ALK        Brent          DAL         JBLU  \
# count   2900.000000  2900.000000  2901.000000  2900.000000  2900.000000
# mean      25.753289    56.375344    67.525664    44.547016    13.784645
# std       13.357412    13.595296    18.142165    10.927760     6.483526
# min        9.040000    23.559999    19.330000    18.523203     3.430000
# 25%       13.900000    45.152500    54.459999    37.673820     6.940000
# 50%       19.895000    57.498137    66.779999    43.084894    15.340000
# 75%       38.110543    65.006178    78.800003    50.274782    19.330000
# max       56.988728    94.471428   127.980003    93.429314    27.020000
#
# Ticker         JETS          LUV          SPY          UAL          VIX
# count   2819.000000  2900.000000  2900.000000  2900.000000  2901.000000
# mean      23.671580    39.641369   353.152712    63.260693    18.368663
# std        4.756990     9.117160   157.213384    21.634158     7.006905
# ...

# %%
# Describe Returns
airline_returns.describe()
# Out:
# Ticker          DAL          UAL          AAL          LUV          ALK  \
# count   2903.000000  2903.000000  2903.000000  2903.000000  2903.000000
# mean       0.000281     0.000283    -0.000493     0.000093    -0.000017
# std        0.024397     0.030115     0.030412     0.022757     0.025446
# min       -0.128539    -0.157938    -0.159437    -0.116124    -0.133399
# 25%       -0.012008    -0.013444    -0.015293    -0.010623    -0.012993
# 50%        0.000456     0.000559     0.000000     0.000376     0.000199
# 75%        0.011992     0.013896     0.014469     0.011241     0.012582
# max        0.128984     0.158363     0.158594     0.116300     0.133279
#
# Ticker         JBLU
# count   2903.000000
# mean      -0.000297
# std        0.031797
# min       -0.165797
# 25%       -0.015365
# 50%        0.000000
# 75%        0.013968
# max        0.165140

# %%
# Annual Volatility
annual_vol = airline_returns.std() * np.sqrt(252)
annual_vol
# Out:
# Ticker
# DAL     0.387289
# UAL     0.478062
# AAL     0.482781
# LUV     0.361252
# ALK     0.403944
# JBLU    0.504767
# dtype: float64

# %%
# Annual Returns
annual_return = airline_returns.mean()*252
annual_return
# Out:
# Ticker
# DAL     0.070928
# UAL     0.071215
# AAL    -0.124205
# LUV     0.023420
# ALK    -0.004220
# JBLU   -0.074763
# dtype: float64

# %%
# Sharpe Ratio
sharpe = annual_return / annual_vol
sharpe
# Out:
# Ticker
# DAL     0.183138
# UAL     0.148965
# AAL    -0.257270
# LUV     0.064830
# ALK    -0.010447
# JBLU   -0.148114
# dtype: float64

# %%
# Correlation
corr = airline_returns.corr()
corr
# Out:
# Ticker       DAL       UAL       AAL       LUV       ALK      JBLU
# Ticker
# DAL     1.000000  0.873145  0.838060  0.755438  0.787891  0.688609
# UAL     0.873145  1.000000  0.830937  0.715729  0.767489  0.678922
# AAL     0.838060  0.830937  1.000000  0.717920  0.732340  0.691182
# LUV     0.755438  0.715729  0.717920  1.000000  0.721809  0.657995
# ALK     0.787891  0.767489  0.732340  0.721809  1.000000  0.689569
# JBLU    0.688609  0.678922  0.691182  0.657995  0.689569  1.000000

# %%
# Ugh so many numbers, I just wish I could SEE the results
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.imshow(corr)

plt.colorbar()

plt.xticks(range(len(corr.columns)),corr.columns)

plt.yticks(range(len(corr.columns)),corr.columns)

plt.title("U.S. Airlines Correlation Matrix")

plt.show()

# %%
# Simple Price Chart of the Ancient Guys (reminds me of my Citi days)
prices[["DAL","UAL","AAL", "LUV"]].plot(figsize=(14,6))
plt.show()

# %%
# Returns Distribution
airline_returns.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'DAL'}>, <Axes: title={'center': 'UAL'}>],
#        [<Axes: title={'center': 'AAL'}>, <Axes: title={'center': 'LUV'}>],
#        [<Axes: title={'center': 'ALK'}>,
#         <Axes: title={'center': 'JBLU'}>]], dtype=object)

# %%
# Rolling Volatility
rolling_vol = airline_returns.rolling(90).std()*np.sqrt(252)
rolling_vol.plot(figsize=(14,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# Thanks for your time, allow me to take you to the next Exhibit (02_Models.ipynb)!
